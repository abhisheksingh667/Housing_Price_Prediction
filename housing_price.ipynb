# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('D:\AI\Projects\Housing_Price_Prediction\data\housing_price_dataset.csv')

# %%
df.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
df.describe()
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
df.isnull().sum()
# Out:
# SquareFeet      0
# Bedrooms        0
# Bathrooms       0
# Neighborhood    0
# YearBuilt       0
# Price           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (50000, 6)

# %%
df.columns
# Out:
# Index(['SquareFeet', 'Bedrooms', 'Bathrooms', 'Neighborhood', 'YearBuilt',
#        'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SquareFeet    50000 non-null  int64
#  1   Bedrooms      50000 non-null  int64
#  2   Bathrooms     50000 non-null  int64
#  3   Neighborhood  50000 non-null  object
#  4   YearBuilt     50000 non-null  int64
#  5   Price         50000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 2.3+ MB

# %%
df.hist(figsize=(15,10))
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.show()

# %%
sns.histplot(df['Price'])
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
sns.boxplot(x=df['Price'])
plt.show()

# %%
plt.figure(figsize=(5,10))

for i ,col in enumerate(df.select_dtypes(include=np.number).columns):
 plt.subplot(4,4,i+1)
 plt.boxplot(df[col])

plt.tight_layout()

# %%
Q1 = df["Price"].quantile(0.25)
Q3 = df["Price"].quantile(0.75)

IQR = Q3-Q1

lower = Q1-1.5*IQR
upper = Q3+1.5*IQR

df = df[(df["Price"]>=lower) & (df["Price"]<=upper)]

# %%
df = pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#        SquareFeet  Bedrooms  Bathrooms  YearBuilt          Price  \
# 0            2126         4          1       1969  215355.283618
# 1            2459         3          2       1980  195014.221626
# 2            1860         2          1       1970  306891.012076
# 3            2294         2          1       1996  206786.787153
# 4            2130         5          2       2001  272436.239065
# ...           ...       ...        ...        ...            ...
# 49995        1282         5          3       1975  100080.865895
# 49996        2854         2          2       1988  374507.656727
# 49997        2979         5          3       1962  384110.555590
# 49998        2596         5          2       1984  380512.685957
# 49999        1572         5          3       2011  221618.583218
#
#        Neighborhood_Suburb  Neighborhood_Urban
# 0                    False               False
# 1                    False               False
# ...

# %%
X = df.drop("Price",axis=1)
y = df['Price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MSE:",mean_squared_error(y_pred,y_test))
print("MAE:",mean_absolute_error(y_pred,y_test))
print("R2:",r2_score(y_test , y_pred))
# Out:
# MSE: 2469323660.3452015
# MAE: 39818.26669096838
# R2: 0.5679752924830054

# %% [markdown]
# #### Ridge Regression

# %%
redge_model = Ridge(alpha=1.0)
redge_model.fit(X_train,y_train)
# Out:
# Ridge()

# %%
redge_pred = redge_model.predict(X_test)

# %%
print(mean_absolute_error(y_test, redge_pred))
print(np.sqrt(mean_squared_error(y_test, redge_pred)))
print(r2_score(y_test, redge_pred))
# Out:
# 39818.25547939107
# 49692.2804040536
# 0.5679754549460628

# %% [markdown]
# ### LASSO REGRESSION

# %%
lasso_model = Lasso(alpha=0.1)
lasso_model.fit(X_train,y_train)
# Out:
# Lasso(alpha=0.1)

# %%
lasso_pred = lasso_model.predict(X_test)

# %%
print("MAE:",mean_absolute_error(y_test, lasso_pred))
print("MSE:",mean_squared_error(y_test, lasso_pred))
print("R2:",r2_score(y_test, lasso_pred))
# Out:
# MAE: 39818.2613598836
# MSE: 2469323155.8860664
# R2: 0.5679753807415087

# %% [markdown]
# ### Comparing Model

# %%
results = pd.DataFrame({
    "Models":["Linear","Ridge","Lasso"],
    "R2":[(r2_score(y_pred,y_test)),(r2_score(y_test, redge_pred)),(r2_score(y_test, lasso_pred))]
})
results
# Out:
#    Models        R2
# 0  Linear  0.247079
# 1   Ridge  0.567975
# 2   Lasso  0.567975

# %%
results.sort_values("R2",ascending=False)
# Out:
#    Models        R2
# 1   Ridge  0.567975
# 2   Lasso  0.567975
# 0  Linear  0.247079

# %%
import pickle
with open("../models/housing_price.pkl", "wb") as f:
 loaded_model = pickle.dump(redge_model, f)
